# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

llm.invoke("hi")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DJK2zZy6RPbt5oXsCnqTW5wWedDeA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cecb2-bfdd-7462-b50f-e7b466128d5e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.prompts import PromptTemplate

prompt=PromptTemplate.from_template("""
You are an helpful assistant.

you are provided with adequete context to process the answer to the user.

Use the 
-----------------------------
 {context}
--------------------------------------------  
 to respond to the user.

Be clear and concise and do not hallucinate while giving answers
""")

# %%
retrieved_context = "mr ambrose is old customer he has 10,000 invested in company"

prompt_format = prompt.format(context=retrieved_context)
prompt_format
# Out:
# '\nYou are an helpful assistant.\n\nyou are provided with adequete context to process the answer to the user.\n\nUse the \n-----------------------------\n mr ambrose is old customer he has 10,000 invested in company\n--------------------------------------------  \n to respond to the user.\n\nBe clear and concise and do not hallucinate while giving answers\n'
